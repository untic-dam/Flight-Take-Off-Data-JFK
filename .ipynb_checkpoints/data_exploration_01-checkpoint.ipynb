# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
sns.set(rc={'figure.figsize':(10,4)})
sns.set_context("paper", rc={"font.size":22,"axes.labelsize":24, "axes":22}) 
sns.color_palette('summer');
sns.set(font_scale = 1.5)

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('data/M1_final.csv')
df_0 = df.copy()

# %% [markdown]
# # Exploration

# %% [markdown]
# ## Quick view

# %%
df.head()
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM DEST  \
# 0     11             1            5                B6   N828JB  CHS
# 1     11             1            5                B6   N992JB  LAX
# 2     11             1            5                B6   N959JB  FLL
# 3     11             1            5                B6   N999JQ  MCO
# 4     11             1            5                DL   N880DN  ATL
#
#    DEP_DELAY  CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  DEP_TIME_M  CRS_ARR_M  \
# 0         -1               124       636        324         323        448
# 1         -7               371      2475        340         333        531
# 2         40               181      1069        301         341        482
# 3         -2               168       944        345         343        513
# 4         -4               139       760        360         356        499
#
#    Temperature Dew Point  Humidity Wind  Wind Speed  Wind Gust  Pressure  \
# ...

# %%
df.shape
# Out:
# (28820, 23)

# %%
df.dtypes
# Out:
# MONTH                  int64
# DAY_OF_MONTH           int64
# DAY_OF_WEEK            int64
# OP_UNIQUE_CARRIER     object
# TAIL_NUM              object
# DEST                  object
# DEP_DELAY              int64
# CRS_ELAPSED_TIME       int64
# DISTANCE               int64
# CRS_DEP_M              int64
# DEP_TIME_M             int64
# CRS_ARR_M              int64
# Temperature            int64
# Dew Point             object
# Humidity               int64
# Wind                  object
# Wind Speed             int64
# Wind Gust              int64
# Pressure             float64
# Condition             object
# sch_dep                int64
# sch_arr                int64
# TAXI_OUT               int64
# dtype: object

# %%
df.describe()
# Out:
#               MONTH  DAY_OF_MONTH   DAY_OF_WEEK     DEP_DELAY  \
# count  28820.000000  28820.000000  28820.000000  28820.000000
# mean       7.894240     16.021096      4.008952      6.374983
# std        4.991723      8.750179      1.985230     38.735144
# min        1.000000      1.000000      1.000000    -22.000000
# 25%        1.000000      8.000000      2.000000     -6.000000
# 50%       11.000000     16.000000      4.000000     -3.000000
# 75%       12.000000     24.000000      6.000000      2.000000
# max       12.000000     31.000000      7.000000   1276.000000
#
#        CRS_ELAPSED_TIME      DISTANCE     CRS_DEP_M    DEP_TIME_M  \
# count      28820.000000  28820.000000  28820.000000  28820.000000
# mean         225.288203   1267.746079    831.003851    828.934698
# std          119.482417    889.343246    299.398525    305.864103
# min           57.000000     94.000000    301.000000      1.000000
# 25%          124.000000    483.000000    545.000000    542.000000
# ...

# %%
df.isna().sum()
# Out:
# MONTH                0
# DAY_OF_MONTH         0
# DAY_OF_WEEK          0
# OP_UNIQUE_CARRIER    0
# TAIL_NUM             0
# DEST                 0
# DEP_DELAY            0
# CRS_ELAPSED_TIME     0
# DISTANCE             0
# CRS_DEP_M            0
# DEP_TIME_M           0
# CRS_ARR_M            0
# Temperature          0
# Dew Point            0
# Humidity             0
# Wind                 2
# Wind Speed           0
# Wind Gust            0
# Pressure             0
# Condition            0
# sch_dep              0
# sch_arr              0
# TAXI_OUT             0
# dtype: int64

# %% [markdown]
# ## Categorical col

# %%
df_obj = df.loc[:, df.dtypes == np.object]

# %%
df_obj
# Out:
#       OP_UNIQUE_CARRIER TAIL_NUM DEST Dew Point Wind     Condition
# 0                    B6   N828JB  CHS        34    W  Fair / Windy
# 1                    B6   N992JB  LAX        34    W  Fair / Windy
# 2                    B6   N959JB  FLL        34    W  Fair / Windy
# 3                    B6   N999JQ  MCO        34    W  Fair / Windy
# 4                    DL   N880DN  ATL        32    W  Fair / Windy
# ...                 ...      ...  ...       ...  ...           ...
# 28815                B6   N216JB  ORH        38    N        Cloudy
# 28816                AA   N104NN  BOS        38    N        Cloudy
# 28817                AS   N581AS  SEA        38    N        Cloudy
# 28818                B6   N957JB  SJU        38    N        Cloudy
# 28819                B6   N958JB  BQN        38    N        Cloudy
#
# [28820 rows x 6 columns]

# %%
#unique values
for obj in df_obj:
    print('\n')
    print(obj)
    print(len(df_obj[obj].unique()))
    print(df_obj[obj].unique())
    print(len(df_obj[obj].unique()))
# Out:
# OP_UNIQUE_CARRIER
# 9
# ['B6' 'DL' 'AA' 'AS' 'MQ' '9E' 'YX' 'HA' 'OO']
# 9
#
#
# TAIL_NUM
# 2092
# ['N828JB' 'N992JB' 'N959JB' ... 'N316NB' 'N976NN' 'N217JQ']
# 2092
#
#
# DEST
# 65
# ['CHS' 'LAX' 'FLL' 'MCO' 'ATL' 'ORD' 'BUF' 'LGB' 'LAS' 'DCA' 'PHX' 'SFO'
#  'SJU' 'SLC' 'BOS' 'SAV' 'SYR' 'MSP' 'SEA' 'MIA' 'PDX' 'TPA' 'BTV' 'IAH'
#  'DEN' 'RSW' 'ORF' 'JAX' 'MSY' 'CLT' 'BNA' 'RDU' 'SAN' 'SJC' 'ROC' 'DFW'
#  'IAD' 'AUS' 'DTW' 'PWM' 'SRQ' 'CMH' 'HNL' 'PBI' 'BWI' 'CLE' 'BUR' 'PIT'
#  'RIC' 'IND' 'CVG' 'SMF' 'ONT' 'SAT' 'PSP' 'OAK' 'ABQ' 'PSE' 'ORH' 'BQN'
#  'STT' 'RNO' 'PHL' 'EGE' 'JAC']
# 65
#
#
# Dew Point
# 64
# ['34' '32' '33' '31' '30' '29' '67' '35' '36' '38' '39' '40' '41' '42'
#  '28' '27' '46' '37' '44' '45' '52' '53' '54' '56' '57' '59' '58' '50'
#  '43' '48' '49' '47' '21' '20' '22' '24' '23' '19' '18' '16' '13' '12'
#  '14' '15' '17' '26' '25' '51' '55' '6\xa0' '9\xa0' '5\xa0' '8\xa0' '10'
#  '4\xa0' '7\xa0' '3\xa0' '2\xa0' '11' '0\xa0' '-1' '1\xa0' '-2' '-3']
# 64
#
#
# ...

# %%
df_obj.isna().sum()
# Out:
# OP_UNIQUE_CARRIER    0
# TAIL_NUM             0
# DEST                 0
# Dew Point            0
# Wind                 2
# Condition            0
# dtype: int64

# %%
s_condition = df.groupby('Condition')['Condition'].count().sort_values(ascending=False)
s_condition
# Out:
# Condition
# Mostly Cloudy            9124
# Fair                     5038
# Cloudy                   4992
# Partly Cloudy            3209
# Light Rain               1865
# Mostly Cloudy / Windy    1442
# Fair / Windy              918
# Partly Cloudy / Windy     582
# Rain                      351
# Cloudy / Windy            341
# Light Rain / Windy        288
# Light Drizzle             194
# Fog                       147
# Wintry Mix                 83
# Light Snow                 76
# Heavy Rain                 54
# Fog / Windy                28
# Rain / Windy               25
# Light Snow / Windy         24
# Light Drizzle / Windy      18
# Heavy Rain / Windy          6
# Drizzle and Fog             5
# Light Freezing Rain         4
# Wintry Mix / Windy          4
# Snow                        2
# Name: Condition, dtype: int64

# %%
s_wind = df.groupby('Wind')['Wind'].count().sort_values(ascending=False)
s_wind
# Out:
# Wind
# W       3273
# NW      3173
# NNW     2570
# WSW     2567
# N       2453
# SW      2354
# WNW     2145
# S       1879
# SSW     1632
# NNE     1280
# ENE     1124
# E       1068
# NE      1044
# CALM     835
# ESE      466
# SE       345
# SSE      315
# VAR      295
# Name: Wind, dtype: int64

# %%
df.loc[df['Wind']=='VAR']
# Out:
#        MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM DEST  \
# 422       11             2            6                DL   N883DN  SJU
# 423       11             2            6                OO   N262SY  ORD
# 424       11             2            6                B6   N187JB  IAH
# 425       11             2            6                9E   N146PQ  BUF
# 426       11             2            6                AA   N830NN  CLT
# ...      ...           ...          ...               ...      ...  ...
# 28305      1            30            4                YX   N211JQ  IND
# 28306      1            30            4                B6   N273JB  BOS
# 28307      1            30            4                YX   N216JQ  CMH
# 28308      1            30            4                9E   N8694A  PWM
# 28309      1            30            4                9E   N910XJ  CLE
#
#        DEP_DELAY  CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  DEP_TIME_M  \
# ...

# %%
df.loc[df['Wind'].isna()]
# Out:
#        MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM DEST  \
# 15156     12            19            4                B6   N648JB  FLL
# 15157     12            19            4                9E   N136EV  PWM
#
#        DEP_DELAY  CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  DEP_TIME_M  \
# 15156         60               189      1069       1275        1335
# 15157          3                83       273       1349        1352
#
#        CRS_ARR_M  Temperature Dew Point  Humidity Wind  Wind Speed  Wind Gust  \
# 15156         24           24        10        55  NaN           0          0
# 15157       1432           24        10        55  NaN           0          0
#
#        Pressure      Condition  sch_dep  sch_arr  TAXI_OUT
# 15156     30.42  Mostly Cloudy       21       33        41
# 15157     30.42  Mostly Cloudy       21       33        40

# %%
sns.countplot(x='OP_UNIQUE_CARRIER', data=df_obj);

# %%
sns.countplot(x='Wind', data=df_obj);

# %%
df.loc[df['Dew Point'] == '7\xa0']
# Out:
#        MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM DEST  \
# 4156      11            13            3                DL   N179DN  LAX
# 4157      11            13            3                DL   N371NW  MIA
# 4158      11            13            3                9E   N324PQ  CLE
# 4159      11            13            3                DL   N873DN  SLC
# 4160      11            13            3                DL   N378DN  FLL
# ...      ...           ...          ...               ...      ...  ...
# 25463      1            21            2                DL   N395DZ  MCO
# 25464      1            21            2                DL   N880DN  DEN
# 25465      1            21            2                DL   N693DL  SLC
# 25466      1            21            2                DL   N883DN  LAS
# 25467      1            21            2                MQ   N809AE  RDU
#
#        DEP_DELAY  CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  DEP_TIME_M  \
# ...

# %% [markdown]
# ## Numerical

# %%
df_numeric = df.loc[:, df.dtypes != np.object]

# %%
df_numeric.head(3)
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK  DEP_DELAY  CRS_ELAPSED_TIME  DISTANCE  \
# 0     11             1            5         -1               124       636
# 1     11             1            5         -7               371      2475
# 2     11             1            5         40               181      1069
#
#    CRS_DEP_M  DEP_TIME_M  CRS_ARR_M  Temperature  Humidity  Wind Speed  \
# 0        324         323        448           48        58          25
# 1        340         333        531           48        58          25
# 2        301         341        482           48        58          25
#
#    Wind Gust  Pressure  sch_dep  sch_arr  TAXI_OUT
# 0         38     29.86        9       17        14
# 1         38     29.86        9       17        15
# 2         38     29.86        9       17        22

# %%
df_num = df_numeric.drop(labels=['MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK'], axis=1)

# %%
df_num.head()
# Out:
#    DEP_DELAY  CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  DEP_TIME_M  CRS_ARR_M  \
# 0         -1               124       636        324         323        448
# 1         -7               371      2475        340         333        531
# 2         40               181      1069        301         341        482
# 3         -2               168       944        345         343        513
# 4         -4               139       760        360         356        499
#
#    Temperature  Humidity  Wind Speed  Wind Gust  Pressure  sch_dep  sch_arr  \
# 0           48        58          25         38     29.86        9       17
# 1           48        58          25         38     29.86        9       17
# 2           48        58          25         38     29.86        9       17
# 3           48        58          25         38     29.86        9       17
# 4           46        58          24         35     29.91        9       17
#
#    TAXI_OUT
# 0        14
# 1        15
# 2        22
# ...

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.heatmap(df_num.corr())
# Out:
# <AxesSubplot:>

# %%
df_num.hist()
# Out:
# array([[<AxesSubplot:title={'center':'DEP_DELAY'}>,
#         <AxesSubplot:title={'center':'CRS_ELAPSED_TIME'}>,
#         <AxesSubplot:title={'center':'DISTANCE'}>,
#         <AxesSubplot:title={'center':'CRS_DEP_M'}>],
#        [<AxesSubplot:title={'center':'DEP_TIME_M'}>,
#         <AxesSubplot:title={'center':'CRS_ARR_M'}>,
#         <AxesSubplot:title={'center':'Temperature'}>,
#         <AxesSubplot:title={'center':'Humidity'}>],
#        [<AxesSubplot:title={'center':'Wind Speed'}>,
#         <AxesSubplot:title={'center':'Wind Gust'}>,
#         <AxesSubplot:title={'center':'Pressure'}>,
#         <AxesSubplot:title={'center':'sch_dep'}>],
#        [<AxesSubplot:title={'center':'sch_arr'}>,
#         <AxesSubplot:title={'center':'TAXI_OUT'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df_num.plt()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-4a01d7901cc3> in <module>
# ----> 1 df_num.plt()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'plt'
